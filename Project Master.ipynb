# %%
import pandas as pd
import numpy as np

# %%
#read all Csv files from each Location
sanfran_data = (pd.read_csv('data/SanFrancisco.csv')).drop(columns=['Unnamed: 0', 'Business ID'])
newyork_data = (pd.read_csv('data/NewYork.csv')).drop(columns=['Unnamed: 0', 'Business ID'])
austin_data = (pd.read_csv('data/AustinTX.csv')).drop(columns=['Unnamed: 0', 'Business ID'])
chicago_data = (pd.read_csv('data/Chicago.csv')).drop(columns=['Unnamed: 0', 'Business ID'])

# %%
# newyork_data.drop(columns=['Unnamed: 0', 'Business ID'])
sanfran_data
# Out:
#                              Business           City State  \
# 0                   Swan Oyster Depot  San Francisco    CA
# 1        Marco Polo Italian Ice Cream  San Francisco    CA
# 2                   Anchor Oyster Bar  San Francisco    CA
# 3                     Chez Maman East  San Francisco    CA
# 4    Shizen Vegan Sushi Bar & Izakaya  San Francisco    CA
# ..                                ...            ...   ...
# 945                           Redford  San Francisco    CA
# 946               Pampanguena Cuisine  San Francisco    CA
# 947                     Wok Shop Cafe  San Francisco    CA
# 948                       Crawstation  San Francisco    CA
# 949                       Okina Sushi  San Francisco    CA
#
#                       Category   Latitude   Longitude Price  Reviews
# 0                      Seafood  37.790939 -122.420796    $$     2709
# 1    Ice Cream & Frozen Yogurt  37.742622 -122.481885     $     1429
# ...

# %%
#create a table discussing the total of sample pulled compared to total places reviewed by yelp

# %%
#North Vs South Vs East Vs West

# %%
#distribution of categories by region
