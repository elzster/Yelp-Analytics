# %% [markdown]
# # Search Query

# %%
import json
import pandas as pd
import numpy as np
import requests
from config import api_key

# %% [markdown]
# # Enter in Answers to Questions

# %%
print("What type of Category would you like to search for? i.e Restaurant")
search_category = input()
print("What city and state are you searching? i.e. New York City, NY")
location = input()
# Out:
# What type of Category would you like to search for? i.e Restaurant
# Restaurant
# What city and state are you searching? i.e. New York City, NY
# Weehawken, NJ

# %%
# print("What type of Category would you like to search for? i.e Restaurant")
# search_category = input()
# print("What city and state are you searching? i.e. New York City, NY")
# location = input()
# print("Offset Page Range? i.e. 50 results per page")
# offset = int(input())

name = []
city = []
state = []
category = []
latitude = []
longitude = []
price = []
review_count = []
business_id = []
rating = []

def query_search(set_num): 
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': 'Bearer {}'.format(api_key),}
    url_params = { #parameters passed to the API
    "categories": search_category,
    "location": location,
    'offset': offset_num,
     "limit":50
     }

    response = requests.get(url, headers=headers, params=url_params)
    return response.json()

# %% [markdown]
# ## Run Query Based On Parameters

# %%
for offset_num in range(2): 
    try:
        response = query_search(offset_num)
        businesses=response['businesses']            
        for x in businesses:
            name.append(x['name'])
            business_id.append(x['id'])
            city.append(x['location']['city'])
            state.append(x['location']['state'])
            latitude.append(x['coordinates']['latitude'])
            longitude.append(x['coordinates']['longitude'])
            review_count.append(x['review_count'])
            rating.append(x['rating'])
            category.append(x['categories'][0]['title'])
            try:
                price.append(x['price'])
            except KeyError:
                price.append(0)
#             print(response)
    except AttributeError:
        print("error at ", offset_num)
    except KeyError:
        print("error at ", offset_num)

# %%
business_df = pd.DataFrame({
    "Business" : name,
    "Business ID": business_id,
    "City": city,
    "State": state,
    "Category": category,
    "Latitude": latitude,
    "Longitude": longitude,
    "Price":price,
    "Reviews": review_count,
    "Rating": rating
})
business_df
# Out:
#                     Business             Business ID       City State  \
# 0              Levain Bakery  H4jJ7XB3CetIr1pg56CczQ   New York    NY
# 1             The Halal Guys  xEnNFXtMLDF5kZDxfaCJgA   New York    NY
# 2                Chart House  _WsfOuvObbp1tH4cBE-jNw  Weehawken    NJ
# 3                  Ippudo NY  44SY464xDHbvOcjDzRbKkQ   New York    NY
# 4               Bibble & Sip  WHRHK3S1mQc3PmhwsGRvbw   New York    NY
# ..                       ...                     ...        ...   ...
# 95  Bengal Tiger Indian Food  x0k5kFArHLijdY8-NEQ7Xg   New York    NY
# 96              Grace Street  MKYhiSeXjahxh9O4Gqnimw   New York    NY
# 97               Dutch Freds  SaYTVG7wHCMDBofHCgXPaA   New York    NY
# 98          Keens Steakhouse  pQuZDnefX038xurT1BhDXA   New York    NY
# 99          Mamoun's Falafel  L-IuiVoFMDSw2K6OAciP1g   New York    NY
#
#           Category   Latitude  Longitude Price  Reviews  Rating
# 0         Bakeries  40.779940 -73.980283    $$     7772     4.5
# 1      Food Stands  40.761756 -73.979230     $     9249     4.0
# 2          Seafood  40.760728 -74.018106   $$$     1361     4.0
# 3            Ramen  40.730920 -73.990150    $$     9849     4.0
# 4     Coffee & Tea  40.762820 -73.985180     $     4593     4.5
# ..             ...        ...        ...   ...      ...     ...
# 95          Indian  40.763167 -73.977131    $$     1724     4.5
# 96    Coffee & Tea  40.747858 -73.986559    $$     2301     4.0
# 97   Cocktail Bars  40.760710 -73.987930    $$     1383     4.5
# 98     Steakhouses  40.750710 -73.986520  $$$$     2455     4.0
# 99  Middle Eastern  40.730287 -74.000438     $     2345     4.0
#
# [100 rows x 10 columns]

# %%
print(len(business_df['Business']))
# Out:
# 100

# %% [markdown]
# ## Save file to a csv using the search location and category

# %%
business_df.to_csv('data/'+(location)+'_'+(search_category)+'.csv')
