# %%
import requests
import json
import pandas as pd
import numpy as np
from pprint import pprint
from config import api_key

name = []
city = []
state = []
category = []
latitude = []
longitude = []
price = []
review_count = []
business_id = []
rating = []

# %%
#testloop


#headers
headers={'Authorization':'Bearer %s' % api_key}
#url for yelp
url='https://api.yelp.com/v3/businesses/search'
#parameters
params = {'term':'smoke shop','location':"Jersey City, NJ", 'limit':50, 'offset': 0}
req=requests.get(url, params=params, headers=headers)

#each time you run this you will burn through your daily amount.
parsed = json.loads(req.text)
businesses = parsed['businesses']
pprint(parsed, depth=4)

#This loop just parses data from the Json request and appends to lists.
for business in businesses:
    name.append(business['name'])
    business_id.append(business['id'])
    city.append(business['location']['city'])
    state.append(business['location']['state'])
    latitude.append(business['coordinates']['latitude'])
    longitude.append(business['coordinates']['longitude'])
    review_count.append(business['review_count'])
    rating.append(business['rating'])
    category.append(business['categories'][0]['title'])
    
    try:
        price.append(business['price'])
    except KeyError:
        price.append(0)
        
business_df = pd.DataFrame({
    "Business" : name,
    "Business ID": business_id,
    "City": city,
    "State": state,
    "Category": category,
    "Latitude": latitude,
    "Longitude": longitude,
    "Price":price,
    "Reviews": review_count
})
business_df
# Out:
# {'businesses': [{'alias': 'smokers-heaven-smoke-and-vape-shop-jersey-city-4',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.73064,
#                                  'longitude': -74.0615399},
#                  'display_phone': '(201) 839-5721',
#                  'distance': 507.4882966670239,
#                  'id': 'CzwBI_CQ6EW0j68UMHzJ-g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sNup23P5kcnLkFuhrZtdrA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '58 Sip Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Jersey City',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07306'},
#                  'name': "Smoker's Heaven Smoke & Vape Shop",
#                  'phone': '+12018395721',
#                  'price': '$',
#                  'rating': 3.5,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/smokers-heaven-smoke-and-vape-shop-jersey-city-4?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'smoke-shop-jersey-city',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.731678,
#                                  'longitude': -74.0666275},
#                  'display_phone': '(201) 653-0100',
#                  'distance': 833.7848896604565,
#                  'id': 'Cfn6LOzyDISx-K5MmrgCMA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/wUSTGTPJQJIklnLERHGoAQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2822 John F Kennedy Blvd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Jersey City',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07306'},
#                  'name': 'Smoke Shop',
#                  'phone': '+12016530100',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/smoke-shop-jersey-city?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'a-1-smoke-shop-jersey-city',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7366253970032,
#                                  'longitude': -74.0516251814294},
#                  'display_phone': '(201) 656-8800',
#                  'distance': 1314.2203368906576,
#                  'id': 'wZINnc3U6HCyceFs3r6F8Q',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/WaaJyMIxKhblYNw0-ced2w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '455 Baldwin Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Jersey City',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07306'},
#                  'name': 'A#1 Smoke Shop',
#                  'phone': '+12016568800',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/a-1-smoke-shop-jersey-city?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'paulus-hook-vape-shop-jersey-city',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.71441, 'longitude': -74.03819},
#                  'display_phone': '(201) 432-2500',
#                  'distance': 2239.873985293924,
#                  'id': 'nFIUiAGZRpXJt3vZJTE8aw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/hSBJPBhPH59eKTdFzgKXCA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '211 Washington St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Jersey City',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07302'},
#                  'name': 'Paulus Hook Vape Shop',
#                  'phone': '+12014322500',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/paulus-hook-vape-shop-jersey-city?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'jersey-city-vape-and-smoke-shop-jersey-city',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.72282, 'longitude': -74.04897},
#                  'display_phone': '(201) 984-0605',
#                  'distance': 969.5692201691608,
#                  'id': '3IaVhoIYG2p3BoBkm3Tlxw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UGug5oSp7lHI06k6dsm3Qg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '355 2nd St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Jersey City',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07302'},
#                  'name': 'Jersey City Vape & Smoke Shop',
#                  'phone': '+12019840605',
#                  'price': '$$',
#                  'rating': 3.0,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jersey-city-vape-and-smoke-shop-jersey-city?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'sky-tobacco-jersey-city',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.7205299,
#                                  'longitude': -74.0425099},
#                  'display_phone': '(201) 432-4071',
#                  'distance': 1570.7192919245413,
#                  'id': 'auzrfOHW5KlHpOEBTZdd4A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aKLBvXhKvbpP_e4JjX9RFg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '344 Grove St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Jersey City',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07302'},
#                  'name': 'Sky Tobacco',
#                  'phone': '+12014324071',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 16,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/sky-tobacco-jersey-city?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'hoboken-smoke-shop-hoboken-2',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7440201,
#                                  'longitude': -74.0293594},
#                  'display_phone': '(201) 683-7978',
#                  'distance': 3206.789365966335,
#                  'id': 'TRM16IfwXsm0XYw6tNOPjg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EnvfqdLorueCJMPY_GteaA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '614 Washington St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Hoboken',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07030'},
#                  'name': 'Hoboken Smoke Shop',
#                  'phone': '+12016837978',
#                  'price': '$$$',
#                  'rating': 3.0,
#                  'review_count': 27,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hoboken-smoke-shop-hoboken-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'urge-smoke-shop-hoboken',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.74501, 'longitude': -74.02892},
#                  'display_phone': '(201) 683-7666',
#                  'distance': 3306.4731863783386,
#                  'id': '9H31VozP9D9amAMhOJ5vnw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/FVdgLUOt-qWMjAIhXBPaWg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '704 Washington St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Hoboken',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07030'},
#                  'name': 'Urge Smoke Shop',
#                  'phone': '+12016837666',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/urge-smoke-shop-hoboken?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'urge-smoke-shop-union-city',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7703781,
#                                  'longitude': -74.0307083},
#                  'display_phone': '(201) 565-8743',
#                  'distance': 5453.7189565904655,
#                  'id': 'haqOyFXW2rAdDJjQXPNvew',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/katbQGDQe0_hnE3gEwCPzQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2813 Bergenline Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Union City',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07087'},
#                  'name': 'Urge Smoke Shop',
#                  'phone': '+12015658743',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 18,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/urge-smoke-shop-union-city?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'canal-smoke-shop-new-york',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7203, 'longitude': -74.00345},
#                  'display_phone': '',
#                  'distance': 4774.433297565264,
#                  'id': 'z-9RB7fyhUNzSWA6qsXYPw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/PVeoqROzHe6v5CHorbPoKA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '342 Canal St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10013'},
#                  'name': 'Canal Smoke Shop',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/canal-smoke-shop-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'smoke-n-clouds-brooklyn-2',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7028634,
#                                  'longitude': -73.9874951},
#                  'display_phone': '(347) 689-3313',
#                  'distance': 6616.233978643916,
#                  'id': 'pVI8VVCwPgM40qV7DqVrDQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wfEzVd23b81ywgAXVlQFvg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '63 Pearl St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': 'Smoke N Clouds',
#                  'phone': '+13476893313',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 4,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/smoke-n-clouds-brooklyn-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'the-smoking-shop-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.733877,
#                                  'longitude': -74.001795},
#                  'display_phone': '(212) 929-1151',
#                  'distance': 4934.328308493182,
#                  'id': 'DCABiBZ3J071F9qOjZdx4g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/biOMrPf9DWUFjsYEZlIUeg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '45 Christopher St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10014'},
#                  'name': 'The Smoking Shop',
#                  'phone': '+12129291151',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 54,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-smoking-shop-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': '200-tobacco-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7548920235106,
#                                  'longitude': -73.9885643217532},
#                  'display_phone': '(646) 649-3177',
#                  'distance': 6764.143191861283,
#                  'id': 'h4YNGXpHIkv4Xooy0mSwUg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/AJKoLATb9aurhhURz-5_MQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '200 west 40th and 7th ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10018'},
#                  'name': '200 Tobacco',
#                  'phone': '+16466493177',
#                  'rating': 5.0,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/200-tobacco-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'kings-of-smoke-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7188722398476,
#                                  'longitude': -73.9908434183168},
#                  'display_phone': '(212) 226-2555',
#                  'distance': 5848.6501859379705,
#                  'id': 'QdxuPWiA09UXkKEaqlHt_Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/blDpQHUjaG7_GYj7x3ugpw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '99 Allen St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10002'},
#                  'name': 'Kings Of Smoke',
#                  'phone': '+12122262555',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/kings-of-smoke-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': '97-smoke-shop-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7953788648941,
#                                  'longitude': -73.9709193181801},
#                  'display_phone': '',
#                  'distance': 10698.730183612699,
#                  'id': 'GiSkWR3Dw-BEBebWSbwK3g',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_tdIaHHJ2XYs-G0_pSzpJg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '2578 Broadway',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10025'},
#                  'name': '97 Smoke Shop',
#                  'phone': '',
#                  'price': '$',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/97-smoke-shop-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'smoke-scene-new-york',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7637122,
#                                  'longitude': -73.9811377},
#                  'display_phone': '(212) 265-1425',
#                  'distance': 7796.756306395873,
#                  'id': '33dLybEPZXG5KWmARAaWEQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LrJN3ucvhIgNQngxC5ht4Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '845 7th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10019'},
#                  'name': 'Smoke Scene',
#                  'phone': '+12122651425',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 16,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/smoke-scene-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'smoke-n-vape-manhattan-4',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7603912,
#                                  'longitude': -73.990799},
#                  'display_phone': '(212) 390-1654',
#                  'distance': 6912.949717549314,
#                  'id': 'e7tLfoO_HdRFEQSsJf_gAQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KrtGEWFJVhqYlxHwGrtcQA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '644 9th Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Manhattan',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10036'},
#                  'name': 'Smoke N Vape',
#                  'phone': '+12123901654',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 28,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/smoke-n-vape-manhattan-4?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'manhattan-tobacco-new-york',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.7681545,
#                                  'longitude': -73.9857203},
#                  'display_phone': '(646) 675-5571',
#                  'distance': 7757.032054093936,
#                  'id': 't_mbjLirfKKGL7A4dJSynA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/n2ovNv_GZltmGph_4UqUlA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '881 9th Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10019'},
#                  'name': 'Manhattan Tobacco',
#                  'phone': '+16466755571',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/manhattan-tobacco-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'herald-smoke-shop-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.74807, 'longitude': -73.98738},
#                  'display_phone': '(212) 643-1858',
#                  'distance': 6547.539952584809,
#                  'id': 'PUDXDZ5ZVpSr5XLao3ArSQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Aljz2L6pO2ly3hgwus9dFg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '39 W 32nd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10001'},
#                  'name': 'Herald Smoke Shop',
#                  'phone': '+12126431858',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/herald-smoke-shop-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'hoboken-cigars-hoboken',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.736179589189,
#                                  'longitude': -74.028962878258},
#                  'display_phone': '(201) 386-5515',
#                  'distance': 2793.863909539621,
#                  'id': 'TU_CDFQnKIh2S56i-sZZdg',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/lkqW3pqEB69jif9uTLSSvQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '77 River St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Hoboken',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07030'},
#                  'name': 'Hoboken Cigars',
#                  'phone': '+12013865515',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 22,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/hoboken-cigars-hoboken?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'davidoff-of-geneva-since-1911-new-york-8',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.7119835,
#                                  'longitude': -74.0152654},
#                  'display_phone': '(212) 897-2866',
#                  'distance': 4061.383007565289,
#                  'id': 'UP3vwYzIp3y1d9HtAjc41w',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9CbK4aVGWFifegZzGM_NLQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '225 Liberty St',
#                               'address2': 'Ste 126',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10281'},
#                  'name': 'Davidoff of Geneva Since 1911',
#                  'phone': '+12128972866',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 8,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/davidoff-of-geneva-since-1911-new-york-8?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'status-lounge-newark-2',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.731653,
#                                  'longitude': -74.161259},
#                  'display_phone': '(973) 752-4722',
#                  'distance': 8593.053998008301,
#                  'id': 'RXZe4JHIXGc6NRF4qqbEiQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6bBDGu1hYGEbbp3bWjPt_Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '41 Congress St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07105'},
#                  'name': 'Status Lounge',
#                  'phone': '+19737524722',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/status-lounge-newark-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'east-west-novelty-union-city',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.781522,
#                                  'longitude': -74.020961},
#                  'display_phone': '(201) 863-9486',
#                  'distance': 6933.454560791143,
#                  'id': 'rCIxXGpJNK7jEgKiS3l4ZA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/vZCfYa__frmLSjNfftquRg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '330 48th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Union City',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07087'},
#                  'name': 'East West Novelty',
#                  'phone': '+12018639486',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 4,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/east-west-novelty-union-city?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'smoke-shop-and-convenience-store-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.72753, 'longitude': -74.0007},
#                  'display_phone': '(212) 598-5851',
#                  'distance': 4962.322581948013,
#                  'id': 'yDj04VuZJVZzyjmbNcaj-Q',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sjIj3ZGWEaSlWNbgT_nXCQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '110 W Houston St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10012'},
#                  'name': 'Smoke Shop & Convenience Store',
#                  'phone': '+12125985851',
#                  'rating': 4.0,
#                  'review_count': 6,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/smoke-shop-and-convenience-store-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'clinton-novelties-smoke-shop-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.72072, 'longitude': -73.98412},
#                  'display_phone': '(212) 777-7733',
#                  'distance': 6391.475920749644,
#                  'id': 'oiEZ0L0XLw6wp4Ew9hL8pw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2eclr5RoijrNJcDJ5Y5YLA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '20 Clinton St',
#                               'address2': 'Ste 1',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10002'},
#                  'name': 'Clinton Novelties Smoke Shop',
#                  'phone': '+12127777733',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 4,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/clinton-novelties-smoke-shop-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'barclay-rex-new-york-7',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.704889911312,
#                                  'longitude': -74.0086724140497},
#                  'display_phone': '(212) 962-3355',
#                  'distance': 4909.944687187946,
#                  'id': 'Bo3rlLSe7V6GNr5N-JuYTw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/qh7oSKXayzN7EVTjiee8eQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '126 Pearl St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10005'},
#                  'name': 'Barclay Rex',
#                  'phone': '+12129623355',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 23,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/barclay-rex-new-york-7?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'cloud-depot-vape-and-smoke-shop-newark',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7282668405799,
#                                  'longitude': -74.1603502924737},
#                  'display_phone': '(973) 589-1582',
#                  'distance': 8498.623567759729,
#                  'id': 'KpyKY2Y--OMdz9tPB-j_rw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Kg2Veq-ZPz6zmB2nEh9STw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '273 Lafayette St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07105'},
#                  'name': 'Cloud Depot Vape & Smoke Shop',
#                  'phone': '+19735891582',
#                  'price': '$',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/cloud-depot-vape-and-smoke-shop-newark?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'midtown-smoke-and-vape-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7543770597024,
#                                  'longitude': -73.9957453399505},
#                  'display_phone': '(646) 688-5779',
#                  'distance': 6207.015829302921,
#                  'id': 'w9Vz7XWRZ7oDQANIBBy17Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/KjUE_u91Irfb4IEzOFDmhg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '454 9th Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10018'},
#                  'name': 'Midtown Smoke and Vape',
#                  'phone': '+16466885779',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 22,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/midtown-smoke-and-vape-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'nassau-grocery-new-york-2',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.70925, 'longitude': -74.0088},
#                  'display_phone': '(212) 349-2219',
#                  'distance': 4678.274332394313,
#                  'id': 'bf85XazWE0NGvC90PY-I6g',
#                  'image_url': '',
#                  'is_closed': False,
#                  'location': {'address1': '59 Nassau St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10038'},
#                  'name': 'Nassau Grocery',
#                  'phone': '+12123492219',
#                  'price': '$',
#                  'rating': 2.0,
#                  'review_count': 1,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/nassau-grocery-new-york-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'belleville-tobacco-and-vape-shop-belleville',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7937509,
#                                  'longitude': -74.1442632},
#                  'display_phone': '(973) 751-3081',
#                  'distance': 10295.947979278586,
#                  'id': 'bC1RwJoq0-pJByjrBzT_ig',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/7drjVl6r8xxlCWyhUcNp_g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '386 Main St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Belleville',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07109'},
#                  'name': 'Belleville Tobacco & Vape Shop',
#                  'phone': '+19737513081',
#                  'rating': 5.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/belleville-tobacco-and-vape-shop-belleville?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'brick-city-vape-and-smoke-shop-newark',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.73075, 'longitude': -74.16137},
#                  'display_phone': '(862) 576-8866',
#                  'distance': 8595.546396771602,
#                  'id': 'uLJO_FGQ1EpPG7rjhO0doA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/G5Xqvio_CwTLiwO90KHNNw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '97 Ferry St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Newark',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07105'},
#                  'name': 'Brick City Vape & Smoke shop',
#                  'phone': '+18625768866',
#                  'rating': 4.0,
#                  'review_count': 1,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/brick-city-vape-and-smoke-shop-newark?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'canna-boys-new-york-2',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.746639251709,
#                                  'longitude': -73.9906005859375},
#                  'display_phone': '(646) 478-7408',
#                  'distance': 6225.894028495913,
#                  'id': 'p-Kt1cJ54aprKyP83kcrYA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qjN3n61PMG-xBlWA4liDJA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '102 W 29th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10001'},
#                  'name': 'Canna Boys',
#                  'phone': '+16464787408',
#                  'rating': 3.0,
#                  'review_count': 5,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/canna-boys-new-york-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'east-village-smoke-shop-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.72939, 'longitude': -73.98434},
#                  'display_phone': '(212) 228-9005',
#                  'distance': 6352.129971563487,
#                  'id': 'y1zlYkyOv1vr29zN8JQSOw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/2oX_B6zOR0jZMMCfarScCA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '177 1st Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10003'},
#                  'name': 'East Village Smoke Shop',
#                  'phone': '+12122289005',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 6,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/east-village-smoke-shop-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'city-smoke-kearny',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.7599719202298,
#                                  'longitude': -74.1514963958036},
#                  'display_phone': '',
#                  'distance': 8598.978445371802,
#                  'id': '4KVbmq_cyUd-hRQIU4NMbg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YyKF930jExmoPPlEitv3Qg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '258 Kearny Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kearny',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07032'},
#                  'name': 'City Smoke',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 1.5,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/city-smoke-kearny?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'havana-on-the-hudson-cigars-weehawken',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.760345,
#                                  'longitude': -74.027877},
#                  'display_phone': '(201) 867-3300',
#                  'distance': 4617.429407443053,
#                  'id': 'Ps8Jq6I7KLF6TptiAi57Eg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aiVjzfo_37cV5EFNZEM21g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1907 Willow Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Weehawken',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NJ',
#                               'zip_code': '07086'},
#                  'name': 'Havana On the Hudson Cigars',
#                  'phone': '+12018673300',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 22,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/havana-on-the-hudson-cigars-weehawken?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'blue-nile-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.73316, 'longitude': -74.00433},
#                  'display_phone': '(646) 336-1118',
#                  'distance': 4713.788337512333,
#                  'id': 'HfaOkOd2PYNOnonyFl1L6A',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IXNjJEjQPyWZeSCN9BMD4A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '324 Bleecker St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10014'},
#                  'name': 'Blue Nile',
#                  'phone': '+16463361118',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 25,
#                  'transactions': [],
# ...
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11217'},
#                  'name': 'Brooklyn Smoke Shop',
#                  'phone': '+13479874210',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 33,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/brooklyn-smoke-shop-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'metro-beer-and-smoke-brooklyn',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7145, 'longitude': -73.958},
#                  'display_phone': '(865) 255-7967',
#                  'distance': 8659.67361744197,
#                  'id': 'YE29xQI-zOdUzVyrSEKVTQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/xYrJEV_6qWUcfLAvL_l6sg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '298 Metropolitan Ave',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Metro Beer & Smoke',
#                  'phone': '+18652557967',
#                  'rating': 4.5,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/metro-beer-and-smoke-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'smoke-zone-new-york-4',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7699165391291,
#                                  'longitude': -73.9577875768773},
#                  'display_phone': '(646) 918-6306',
#                  'distance': 9840.068616169327,
#                  'id': 'RRox1QH1un4mCXafpoPM9w',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/_M8KL08GF0lRrQp9i6wq7g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1411 2nd Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10021'},
#                  'name': 'Smoke Zone',
#                  'phone': '+16469186306',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/smoke-zone-new-york-4?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'db-smoke-shop-brooklyn',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.68063, 'longitude': -73.97731},
#                  'display_phone': '(718) 857-9559',
#                  'distance': 8598.594766825954,
#                  'id': 'hf6flMdJbak_Cpte3Y40vA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3wdd-HqJtcWlhsYFs39tYw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '65 5th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11217'},
#                  'name': 'DB Smoke shop',
#                  'phone': '+17188579559',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 7,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/db-smoke-shop-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'cigar-n-vape-brooklyn',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.6690315,
#                                  'longitude': -73.9867848},
#                  'display_phone': '(718) 788-1812',
#                  'distance': 8851.286995100703,
#                  'id': 'x5hdB8E4Hp-6J3D_NKuK5A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/88swJA3YdtQVwqgRtM8Ltw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '452 5th Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11215'},
#                  'name': 'Cigar N Vape',
#                  'phone': '+17187881812',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 10,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/cigar-n-vape-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'classic-smoke-shop-new-york',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.72863, 'longitude': -73.99938},
#                  'display_phone': '(212) 777-9272',
#                  'distance': 5078.501356719255,
#                  'id': 'v8KgY3liJ3xU90YIEsMTlw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iPbTrSPLK6eKuh0TofF9OA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '206 Thompson St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10012'},
#                  'name': 'Classic Smoke Shop',
#                  'phone': '+12127779272',
#                  'price': '$$$',
#                  'rating': 3.0,
#                  'review_count': 3,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/classic-smoke-shop-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'mikeys-smoke-shop-brooklyn',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.69083, 'longitude': -73.99149},
#                  'display_phone': '(718) 875-1139',
#                  'distance': 6977.690894886479,
#                  'id': 'hBJR0yhqacXqsTh52Vp0Gw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iSLeyQ2ezN6LNezy9LY8kQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '60 Schermerhorn St',
#                               'address2': None,
#                               'address3': None,
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': "Mikey's Smoke Shop",
#                  'phone': '+17188751139',
#                  'price': '$$',
#                  'rating': 2.5,
#                  'review_count': 2,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/mikeys-smoke-shop-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'}],
#  'region': {'center': {'latitude': 40.726434262123384,
#                        'longitude': -74.05952453613281}},
#  'total': 153}
#                              Business             Business ID         City  \
# 0   Smoker's Heaven Smoke & Vape Shop  CzwBI_CQ6EW0j68UMHzJ-g  Jersey City
# 1                          Smoke Shop  Cfn6LOzyDISx-K5MmrgCMA  Jersey City
# 2                      A#1 Smoke Shop  wZINnc3U6HCyceFs3r6F8Q  Jersey City
# 3               Paulus Hook Vape Shop  nFIUiAGZRpXJt3vZJTE8aw  Jersey City
# 4       Jersey City Vape & Smoke Shop  3IaVhoIYG2p3BoBkm3Tlxw  Jersey City
# 5                         Sky Tobacco  auzrfOHW5KlHpOEBTZdd4A  Jersey City
# 6                  Hoboken Smoke Shop  TRM16IfwXsm0XYw6tNOPjg      Hoboken
# 7                     Urge Smoke Shop  9H31VozP9D9amAMhOJ5vnw      Hoboken
# 8                     Urge Smoke Shop  haqOyFXW2rAdDJjQXPNvew   Union City
# 9                    Canal Smoke Shop  z-9RB7fyhUNzSWA6qsXYPw     New York
# 10                     Smoke N Clouds  pVI8VVCwPgM40qV7DqVrDQ     Brooklyn
# 11                   The Smoking Shop  DCABiBZ3J071F9qOjZdx4g     New York
# 12                        200 Tobacco  h4YNGXpHIkv4Xooy0mSwUg     New York
# 13                     Kings Of Smoke  QdxuPWiA09UXkKEaqlHt_Q     New York
# 14                      97 Smoke Shop  GiSkWR3Dw-BEBebWSbwK3g     New York
# 15                        Smoke Scene  33dLybEPZXG5KWmARAaWEQ     New York
# 16                       Smoke N Vape  e7tLfoO_HdRFEQSsJf_gAQ    Manhattan
# 17                  Manhattan Tobacco  t_mbjLirfKKGL7A4dJSynA     New York
# 18                  Herald Smoke Shop  PUDXDZ5ZVpSr5XLao3ArSQ     New York
# 19                     Hoboken Cigars  TU_CDFQnKIh2S56i-sZZdg      Hoboken
# 20      Davidoff of Geneva Since 1911  UP3vwYzIp3y1d9HtAjc41w     New York
# 21                      Status Lounge  RXZe4JHIXGc6NRF4qqbEiQ       Newark
# 22                  East West Novelty  rCIxXGpJNK7jEgKiS3l4ZA   Union City
# 23     Smoke Shop & Convenience Store  yDj04VuZJVZzyjmbNcaj-Q     New York
# 24       Clinton Novelties Smoke Shop  oiEZ0L0XLw6wp4Ew9hL8pw     New York
# 25                        Barclay Rex  Bo3rlLSe7V6GNr5N-JuYTw     New York
# 26      Cloud Depot Vape & Smoke Shop  KpyKY2Y--OMdz9tPB-j_rw       Newark
# 27             Midtown Smoke and Vape  w9Vz7XWRZ7oDQANIBBy17Q     New York
# 28                     Nassau Grocery  bf85XazWE0NGvC90PY-I6g     New York
# 29     Belleville Tobacco & Vape Shop  bC1RwJoq0-pJByjrBzT_ig   Belleville
# 30       Brick City Vape & Smoke shop  uLJO_FGQ1EpPG7rjhO0doA       Newark
# 31                         Canna Boys  p-Kt1cJ54aprKyP83kcrYA     New York
# 32            East Village Smoke Shop  y1zlYkyOv1vr29zN8JQSOw     New York
# 33                         City Smoke  4KVbmq_cyUd-hRQIU4NMbg       Kearny
# 34        Havana On the Hudson Cigars  Ps8Jq6I7KLF6TptiAi57Eg    Weehawken
# 35                          Blue Nile  HfaOkOd2PYNOnonyFl1L6A     New York
# 36                     559 Smoke Shop  -hvU8Lf0fHYnOJPqrg829w  South Slope
# 37              Rodriguez Best Cigars  ODXqN7XtEBlf04ETWOlyRw  Jersey City
# 38                  NYC Smokes & More  -4GDQmgVSMyR56sZNWcd5A     New York
# 39             Jubilee Vape and Smoke  cMKWvKYptCS53j-IJxzALg     New York
# 40               Jubilee Smoke & Vape  zIS1f9H_yFb8-nsTQ8jqJQ     New York
# 41                         Cigarillos  gO-c2VQ41cIk_I04kwAYPA     New York
# 42                       Prime Hookah  ECEkgLeTVBlTE-Dt109UVQ      Bayonne
# 43                Brooklyn Smoke Shop  q8tmLaEkNBnKufr0aiQxFw     Brooklyn
# 44                 Metro Beer & Smoke  YE29xQI-zOdUzVyrSEKVTQ     Brooklyn
# 45                         Smoke Zone  RRox1QH1un4mCXafpoPM9w     New York
# 46                      DB Smoke shop  hf6flMdJbak_Cpte3Y40vA     Brooklyn
# 47                       Cigar N Vape  x5hdB8E4Hp-6J3D_NKuK5A     Brooklyn
# 48                 Classic Smoke Shop  v8KgY3liJ3xU90YIEsMTlw     New York
# 49                 Mikey's Smoke Shop  hBJR0yhqacXqsTh52Vp0Gw     Brooklyn
#
#    State       Category   Latitude  Longitude Price  Reviews
# 0     NJ     Vape Shops  40.730640 -74.061540     $        5
# 1     NJ     Vape Shops  40.731678 -74.066627    $$        7
# 2     NJ  Tobacco Shops  40.736625 -74.051625    $$        5
# 3     NJ  Tobacco Shops  40.714410 -74.038190    $$        3
# 4     NJ  Tobacco Shops  40.722820 -74.048970    $$        5
# 5     NJ  Tobacco Shops  40.720530 -74.042510    $$       16
# 6     NJ  Tobacco Shops  40.744020 -74.029359   $$$       27
# 7     NJ  Tobacco Shops  40.745010 -74.028920     $        7
# 8     NJ  Tobacco Shops  40.770378 -74.030708    $$       18
# 9     NY     Vape Shops  40.720300 -74.003450    $$        1
# 10    NY     Vape Shops  40.702863 -73.987495    $$        4
# 11    NY  Tobacco Shops  40.733877 -74.001795    $$       54
# 12    NY     Vape Shops  40.754892 -73.988564     0        2
# 13    NY     Vape Shops  40.718872 -73.990843     0        1
# 14    NY     Vape Shops  40.795379 -73.970919     $        1
# 15    NY  Tobacco Shops  40.763712 -73.981138    $$       16
# 16    NY  Tobacco Shops  40.760391 -73.990799    $$       28
# 17    NY  Tobacco Shops  40.768155 -73.985720     0        1
# 18    NY  Tobacco Shops  40.748070 -73.987380     0        1
# 19    NJ  Tobacco Shops  40.736180 -74.028963    $$       22
# 20    NY  Tobacco Shops  40.711984 -74.015265   $$$        8
# 21    NJ    Hookah Bars  40.731653 -74.161259     0        1
# 22    NJ     Gift Shops  40.781522 -74.020961    $$        4
# 23    NY     Vape Shops  40.727530 -74.000700     0        6
# 24    NY  Tobacco Shops  40.720720 -73.984120   $$$        4
# 25    NY  Tobacco Shops  40.704890 -74.008672    $$       23
# 26    NJ     Vape Shops  40.728267 -74.160350     $        1
# 27    NY     Vape Shops  40.754377 -73.995745    $$       22
# 28    NY  Tobacco Shops  40.709250 -74.008800     $        1
# 29    NJ  Tobacco Shops  40.793751 -74.144263     0        1
# 30    NJ     Vape Shops  40.730750 -74.161370     0        1
# 31    NY  Tobacco Shops  40.746639 -73.990601     0        5
# 32    NY  Tobacco Shops  40.729390 -73.984340     $        6
# 33    NJ  Tobacco Shops  40.759972 -74.151496    $$        3
# 34    NJ  Tobacco Shops  40.760345 -74.027877    $$       22
# 35    NY  Tobacco Shops  40.733160 -74.004330    $$       25
# 36    NY     Vape Shops  40.666140 -73.991970     0        1
# 37    NJ  Tobacco Shops  40.754683 -74.043540    $$        1
# 38    NY  Tobacco Shops  40.729331 -74.000738    $$        4
# 39    NY     Vape Shops  40.715110 -74.007580     0        5
# 40    NY  Tobacco Shops  40.776928 -73.957250     0        7
# 41    NY  Tobacco Shops  40.725292 -74.002922    $$       22
# 42    NJ  Tobacco Shops  40.662620 -74.118990     $        4
# 43    NY  Tobacco Shops  40.681565 -73.975946    $$       33
# 44    NY     Vape Shops  40.714500 -73.958000     0        3
# 45    NY  Tobacco Shops  40.769917 -73.957788    $$        3
# 46    NY  Tobacco Shops  40.680630 -73.977310    $$        7
# 47    NY     Vape Shops  40.669032 -73.986785    $$       10
# 48    NY  Tobacco Shops  40.728630 -73.999380   $$$        3
# 49    NY  Tobacco Shops  40.690830 -73.991490    $$        2

# %%
business_df.to_csv('NewYork.csv')

# %%
new_df = business_df.drop_duplicates(keep=False)

# %%
new_df
# Out:
#                                Business             Business ID      City  \
# 3899  Mable's Smokehouse & Banquet Hall  nsAU6F2vmdnphmfIa_RuWg  Brooklyn
#
#      State  Category   Latitude  Longitude Price  Reviews
# 3899    NY  Barbeque  40.721189    -73.957    $$      813
