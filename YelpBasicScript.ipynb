# %%
import requests
import json
import pandas as pd
import numpy as np
from pprint import pprint
from config import api_key

# %%
name = []
city = []
state = []
category = []
latitude = []
longitude = []
price = []
review_count = []
business_id = []
rating = []

# %%
#testloop


#headers
headers={'Authorization':'Bearer %s' % api_key}
#url for yelp
url='https://api.yelp.com/v3/businesses/search'
#parameters
params = {'term':'pokebowl','location':"O'ahu, HI", 'limit':20, 'offset': 0}
req=requests.get(url, params=params, headers=headers)

#each time you run this you will burn through your daily amount.
parsed = json.loads(req.text)

# %%
pprint(parsed, depth=4)
# Out:
# {'businesses': [{'alias': 'aloha-cones-honolulu-5',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 21.33182, 'longitude': -157.86636},
#                  'display_phone': '(808) 842-7653',
#                  'distance': 19647.31007371239,
#                  'id': '1Ypoffv6kEKzWllJUDgafw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tVAz5GUXoKvQsHnPrBWHEw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1339 N School St',
#                               'address2': 'Ste 103',
#                               'address3': '',
#                               'city': 'Honolulu',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96817'},
#                  'name': 'Aloha Cones',
#                  'phone': '+18088427653',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 381,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/aloha-cones-honolulu-5?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'ono-seafood-honolulu',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 21.281391,
#                                  'longitude': -157.813885},
#                  'display_phone': '(808) 732-4806',
#                  'distance': 27310.81702505731,
#                  'id': 'GG55nmUtP4VvH3eoGLqhwQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/LfjQ5JNk46Dmk95G0hpEeg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '747 Kapahulu Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Honolulu',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96816'},
#                  'name': 'Ono Seafood',
#                  'phone': '+18087324806',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 3111,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ono-seafood-honolulu?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'poke-on-da-run-pearl-city-2',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 21.3913588368539,
#                                  'longitude': -157.971238978207},
#                  'display_phone': '(808) 455-4502',
#                  'distance': 10242.426297092998,
#                  'id': 'f-Ft8wE_vaLyuvcQ1Qrd4A',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/f8HSSDUktsrz5zLI3b5xEA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '909 Lehua Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Pearl City',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96782'},
#                  'name': 'Poke On Da Run',
#                  'phone': '+18084554502',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 534,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/poke-on-da-run-pearl-city-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'highway-inn-kakaako-honolulu-2',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 21.297684,
#                                  'longitude': -157.861418},
#                  'display_phone': '(808) 954-4955',
#                  'distance': 23213.772074853798,
#                  'id': 'xoyask-Bn61jN__Hl5DmpA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yzc04ku0W59uXVc6rP7Xlw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '680 Ala Moana Blvd',
#                               'address2': 'Ste 105',
#                               'address3': '',
#                               'city': 'Honolulu',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96813'},
#                  'name': "Highway Inn Kaka'ako",
#                  'phone': '+18089544955',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1139,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/highway-inn-kakaako-honolulu-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'ocean-taste-honolulu-2',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 21.296171,
#                                  'longitude': -157.855018802719},
#                  'display_phone': '(808) 636-0877',
#                  'distance': 23672.500650225247,
#                  'id': '6CwX48RZ22BPE63VQy5gPw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/UF_80Nw0WqIGw4kqxkneAg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '333 Ward Ave',
#                               'address2': 'Ste 65',
#                               'address3': None,
#                               'city': 'Honolulu',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96814'},
#                  'name': 'Ocean Taste',
#                  'phone': '+18086360877',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 90,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/ocean-taste-honolulu-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'pokeway-honolulu-2',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 21.308853,
#                                  'longitude': -157.860542},
#                  'display_phone': '(808) 206-1006',
#                  'distance': 22155.210938346125,
#                  'id': 'Bt4HTrsO9jS6bFh4bwzPtw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yQxbtiB_yMUaTMMDO2ekCQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1003 Bishop St',
#                               'address2': 'Ste 145',
#                               'address3': None,
#                               'city': 'Honolulu',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96813'},
#                  'name': 'Pokeway',
#                  'phone': '+18082061006',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 77,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/pokeway-honolulu-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'alicias-market-honolulu',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 21.3244000570156,
#                                  'longitude': -157.884616989549},
#                  'display_phone': '(808) 841-1921',
#                  'distance': 19487.677016194342,
#                  'id': 'wKZ_pBlsUIDrs0IAeOY5wA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Sv1h8-zLLWcrHyHNcjwm_w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '267 Mokauea St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Honolulu',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96819'},
#                  'name': "Alicia's Market",
#                  'phone': '+18088411921',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 695,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/alicias-market-honolulu?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'poke-and-box-honolulu',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 21.29104, 'longitude': -157.84317},
#                  'display_phone': '(808) 892-5252',
#                  'distance': 24735.71467732203,
#                  'id': 'Nb1237DwzszivCvEtxUPfA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SissYB_GX0Y7eCG_G9i91g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1450 Ala Moana Blvd',
#                               'address2': 'Ste 1801',
#                               'address3': 'Ala Moana Center Makai Food Ct',
#                               'city': 'Honolulu',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96814'},
#                  'name': 'Poke & Box',
#                  'phone': '+18088925252',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 229,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/poke-and-box-honolulu?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'poke-stop-waipahu',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 21.3776824784532,
#                                  'longitude': -158.025444593254},
#                  'display_phone': '(808) 676-8100',
#                  'distance': 13340.90906059444,
#                  'id': 'uxSoovoMkNFeNK8Sc8tDPw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BaKrNxP9paV8VK1mey4bkQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '94 -050 Farrington Hwy',
#                               'address2': 'Ste E4',
#                               'address3': '',
#                               'city': 'Waipahu',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96797'},
#                  'name': 'Poke Stop',
#                  'phone': '+18086768100',
#                  'price': '$$',
#                  'rating': 3.5,
#                  'review_count': 276,
#                  'transactions': ['delivery', 'pickup'],
#                  'url': 'https://www.yelp.com/biz/poke-stop-waipahu?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'fresh-catch-honolulu',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 21.28805, 'longitude': -157.81017},
#                  'display_phone': '(808) 735-7653',
#                  'distance': 26934.148931897813,
#                  'id': '7bncPlKtc6LBfcSV4E00Lg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/33QTw59cV5SAP6dMwKFMDA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '3109 Waialae Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Honolulu',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96816'},
#                  'name': 'Fresh Catch',
#                  'phone': '+18087357653',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 959,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/fresh-catch-honolulu?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'the-hibachi-kailua',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 21.3932103601737,
#                                  'longitude': -157.739881686866},
#                  'display_phone': '(808) 263-7980',
#                  'distance': 25280.762620143178,
#                  'id': 'XJiZVSQYudM1_BA8v0tIdQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/je-N_eOPQ5jP33KdnjPgLw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '515 Kailua Rd',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Kailua',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96734'},
#                  'name': 'The Hibachi',
#                  'phone': '+18082637980',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 635,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-hibachi-kailua?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'plantation-tavern-kapolei',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 21.3372989618741,
#                                  'longitude': -158.080626157217},
#                  'display_phone': '(808) 888-4299',
#                  'distance': 20215.439609527024,
#                  'id': 'cmH8OQjZsJGK08kAy6vkZw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/xwSkFdNJUOnkpIcpDCVXUQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '590 Farrington Hwy',
#                               'address2': 'Ste 536',
#                               'address3': '',
#                               'city': 'Kapolei',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'HI',
#                               'zip_code': '96707'},
#                  'name': 'Plantation Tavern',
#                  'phone': '+18088884299',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 853,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/plantation-tavern-kapolei?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'}],
#  'region': {'center': {'latitude': 21.483236134238684,
#                        'longitude': -157.96417236328125}},
#  'total': 13}

# %%
businesses = parsed['businesses']

# %%
#This loop just parses data from the Json request and appends to lists.
for business in businesses:
    name.append(business['name'])
    business_id.append(business['id'])
    city.append(business['location']['city'])
    state.append(business['location']['state'])
    latitude.append(business['coordinates']['latitude'])
    longitude.append(business['coordinates']['longitude'])
    review_count.append(business['review_count'])
    rating.append(business['rating'])
    category.append(business['categories'][0]['title'])
    
    try:
        price.append(business['price'])
    except KeyError:
        price.append(0)

# %%
hawaii_df = pd.DataFrame({
    "Business" : name,
    "Business ID": business_id,
    "City": city,
    "State": state,
    "Category": category,
    "Latitude": latitude,
    "Longitude": longitude,
    "Price":price,
    "Reviews": review_count
})

# %%
hawaii_df
# Out:
#                 Business             Business ID        City State  \
# 0            Aloha Cones  1Ypoffv6kEKzWllJUDgafw    Honolulu    HI
# 1            Ono Seafood  GG55nmUtP4VvH3eoGLqhwQ    Honolulu    HI
# 2         Poke On Da Run  f-Ft8wE_vaLyuvcQ1Qrd4A  Pearl City    HI
# 3   Highway Inn Kaka'ako  xoyask-Bn61jN__Hl5DmpA    Honolulu    HI
# 4            Ocean Taste  6CwX48RZ22BPE63VQy5gPw    Honolulu    HI
# 5                Pokeway  Bt4HTrsO9jS6bFh4bwzPtw    Honolulu    HI
# 6        Alicia's Market  wKZ_pBlsUIDrs0IAeOY5wA    Honolulu    HI
# 7             Poke & Box  Nb1237DwzszivCvEtxUPfA    Honolulu    HI
# 8              Poke Stop  uxSoovoMkNFeNK8Sc8tDPw     Waipahu    HI
# 9            Fresh Catch  7bncPlKtc6LBfcSV4E00Lg    Honolulu    HI
# 10           The Hibachi  XJiZVSQYudM1_BA8v0tIdQ      Kailua    HI
# 11     Plantation Tavern  cmH8OQjZsJGK08kAy6vkZw     Kapolei    HI
#
#            Category   Latitude   Longitude Price  Reviews
# 0        Sushi Bars  21.331820 -157.866360    $$      381
# 1           Seafood  21.281391 -157.813885     $     3111
# 2          Hawaiian  21.391359 -157.971239    $$      534
# 3          Hawaiian  21.297684 -157.861418    $$     1139
# 4              Poke  21.296171 -157.855019     $       90
# 5              Poke  21.308853 -157.860542     $       77
# 6           Grocery  21.324400 -157.884617    $$      695
# 7              Poke  21.291040 -157.843170    $$      229
# 8          Hawaiian  21.377682 -158.025445    $$      276
# 9          Hawaiian  21.288050 -157.810170    $$      959
# 10  Seafood Markets  21.393210 -157.739882    $$      635
# 11         Hawaiian  21.337299 -158.080626    $$      853

# %%
# business_df.to_csv('BrunswickBurgers.csv')
