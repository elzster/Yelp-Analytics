# %% [markdown]
# # Working Search Query

# %%
import json
import pandas as pd
import numpy as np
import requests
from config import api_key

# %%
## define a function to search for restaurants that have burgers or beer

# %%
name = []
city = []
state = []
category = []
latitude = []
longitude = []
price = []
review_count = []
business_id = []
rating = []

# %%
def query_search(set_num): 
    url = 'https://api.yelp.com/v3/businesses/search'
    headers = {
        'Authorization': 'Bearer {}'.format(api_key),}
    url_params = { #parameters passed to the API
    "categories": 'restaurant',
    "location":'New York City, NY',
    'offset': offset_num,
     "limit":50
     }

    response = requests.get(url, headers=headers, params=url_params)
    return response.json()

# %% [markdown]
# ## Run Query Based On Parameters

# %%
for offset_num in range(1): 
    try:
        response = query_search(offset_num)
        businesses=response['businesses']            
        for x in businesses:
            name.append(x['name'])
            business_id.append(x['id'])
            city.append(x['location']['city'])
            state.append(x['location']['state'])
            latitude.append(x['coordinates']['latitude'])
            longitude.append(x['coordinates']['longitude'])
            review_count.append(x['review_count'])
            rating.append(x['rating'])
            category.append(x['categories'][0]['title'])
            try:
                price.append(x['price'])
            except KeyError:
                price.append(0)
#             print(offset_num)
#             print(response)
    except AttributeError:
        print("error at ", offset_num)
    except KeyError:
        print("error at ", offset_num)

# %%
business_df = pd.DataFrame({
    "Business" : name,
    "Business ID": business_id,
    "City": city,
    "State": state,
    "Category": category,
    "Latitude": latitude,
    "Longitude": longitude,
    "Price":price,
    "Reviews": review_count,
    "Rating": rating
})

# %%
business_df
# Out:
#                            Business             Business ID      City State  \
# 0                     Levain Bakery  H4jJ7XB3CetIr1pg56CczQ  New York    NY
# 1                    The Halal Guys  xEnNFXtMLDF5kZDxfaCJgA  New York    NY
# 2               Katz's Delicatessen  V7lXZKBDzScDeGB8JmnzSA  New York    NY
# 3                         Ippudo NY  44SY464xDHbvOcjDzRbKkQ  New York    NY
# 4    The Metropolitan Museum of Art  jVncyqXwlx_D9f2xZn05tg  New York    NY
# ..                              ...                     ...       ...   ...
# 295                     ABC Kitchen  dMhRafXdr765DHe0k-QfaQ  New York    NY
# 296                  Rice To Riches  HxC2ZN010NxAFwjTqUVpzw  New York    NY
# 297                           Traif  qLLxS7RwNEjP_jq_KQrPfA  Brooklyn    NY
# 298                Molly's Cupcakes  Hs1TH_4FpyzbX6_J5r1XXg  New York    NY
# 299                   Angel's Share  ZD22cMZvSmfNsXS9vKizGA  New York    NY
#
#            Category   Latitude  Longitude Price  Reviews  Rating
# 0          Bakeries  40.779940 -73.980283    $$     7769     4.5
# 1       Food Stands  40.761756 -73.979230     $     9252     4.0
# 2             Delis  40.722237 -73.987430    $$    11697     4.0
# 3             Ramen  40.730920 -73.990150    $$     9845     4.0
# 4       Art Museums  40.779254 -73.962884     0     2762     4.5
# ..              ...        ...        ...   ...      ...     ...
# 295  American (New)  40.738085 -73.989472   $$$     2919     4.0
# 296        Desserts  40.721845 -73.995802    $$     2971     4.0
# 297  American (New)  40.710658 -73.958872   $$$     1830     4.5
# 298        Bakeries  40.730140 -74.002480    $$     1623     4.5
# 299   Cocktail Bars  40.729710 -73.989149    $$     2061     4.5
#
# [300 rows x 10 columns]

# %%
# business_df.to_csv('data/SanFrancisco.csv')
