# %%
import requests
import json
import pandas as pd
import numpy as np
from pprint import pprint
from config import api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8963164d505e> in <module>
#       4 import numpy as np
#       5 from pprint import pprint
# ----> 6 from config import api_key
#
# ModuleNotFoundError: No module named 'config'

# %%
name = []
city = []
state = []
category = []
latitude = []
longitude = []
price = []
review_count = []
business_id = []
rating = []

# %%
#testloop


#headers
headers={'Authorization':'Bearer %s' % api_key}
#url for yelp
url='https://api.yelp.com/v3/businesses/search'
#parameters
params = {'term':'restaurant','location':"New York City, NY", 'limit':50, 'offset': 0}
req=requests.get(url, params=params, headers=headers)

#each time you run this you will burn through your daily amount.
parsed = json.loads(req.text)

# %%
pprint(parsed, depth=4)
# Out:
# {'businesses': [{'alias': 'upstate-new-york-2',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7263139141197,
#                                  'longitude': -73.9864901976935},
#                  'display_phone': '(646) 791-5400',
#                  'distance': 2411.9187177986864,
#                  'id': 'ehUuSk5gPTCQmwS_ubgKRA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RvnUVU7MF7DT0RzNL-EebQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '95 1st Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10003'},
#                  'name': 'Upstate',
#                  'phone': '+16467915400',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1783,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/upstate-new-york-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'amélie-new-york',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#                  'display_phone': '(212) 533-2962',
#                  'distance': 3038.8699032940094,
#                  'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '22 W 8th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10011'},
#                  'name': 'Amélie',
#                  'phone': '+12125332962',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 2562,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'clinton-street-baking-company-new-york-5',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.721128,
#                                  'longitude': -73.983933},
#                  'display_phone': '(646) 602-6263',
#                  'distance': 1950.282829638887,
#                  'id': 'nU4XBdvxDABXqZ6CnB8Dig',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DWHdizJ9bKbXN4yq6nbwAA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '4 Clinton St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10002'},
#                  'name': 'Clinton Street Baking Company',
#                  'phone': '+16466026263',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 4847,
#                  'transactions': ['restaurant_reservation',
#                                   'pickup',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/clinton-street-baking-company-new-york-5?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'lovemama-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7303859,
#                                  'longitude': -73.9860613},
#                  'display_phone': '(212) 254-5370',
#                  'distance': 2858.7729410008346,
#                  'id': 'jjJc_CrkB2HodEinB6cWww',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '174 2nd Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10003'},
#                  'name': 'LoveMama',
#                  'phone': '+12122545370',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 4562,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/lovemama-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'bocaphê-new-york-3',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.722046,
#                                  'longitude': -73.997557},
#                  'display_phone': '(646) 882-1939',
#                  'distance': 1866.3436634084576,
#                  'id': 'C2o3Iw-DXjoUJFgQIbiqkQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Ck7z-CGvku5kJDPyRkIfew/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '222 Lafayette St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10012'},
#                  'name': 'BoCaphe',
#                  'phone': '+16468821939',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1288,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/bocaph%C3%AA-new-york-3?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'thai-villa-new-york-2',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.73902, 'longitude': -73.99065},
#                  'display_phone': '(212) 802-9999',
#                  'distance': 3744.570399827637,
#                  'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/OgCU9NPFIl8hF_04Zani9w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '5 E 19th St',
#                               'address2': 'G Floor',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10003'},
#                  'name': 'Thai Villa',
#                  'phone': '+12128029999',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 2876,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'barn-joo-35-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.74964, 'longitude': -73.98582},
#                  'display_phone': '(212) 564-4430',
#                  'distance': 4968.473297353009,
#                  'id': 'xZ96vaoL-cQjfotmUKtjJQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1R5CgYlK5qGUhKZOvZThKw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '34 W 35th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10001'},
#                  'name': 'Barn Joo 35',
#                  'phone': '+12125644430',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1725,
#                  'transactions': ['restaurant_reservation',
#                                   'pickup',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/barn-joo-35-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'anytime-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.74779, 'longitude': -73.98674},
#                  'display_phone': '(646) 669-7733',
#                  'distance': 4761.966725883583,
#                  'id': 'VvsZAnEwU4c8Xkyrzx05Nw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S-K4D44wXoqw-wTL4kX2cQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '23 W 32nd St',
#                               'address2': 'Fl 3',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10001'},
#                  'name': 'Anytime',
#                  'phone': '+16466697733',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 911,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/anytime-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'jacobs-pickles-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7866504411994,
#                                  'longitude': -73.9755284786224},
#                  'display_phone': '(212) 470-5566',
#                  'distance': 9166.964737863183,
#                  'id': 'xt4sa64WOrpJvZBDPNPNYg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/167Rl2s1oMge_2ZSDD1z0A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '509 Amsterdam Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10024'},
#                  'name': "Jacob's Pickles",
#                  'phone': '+12124705566',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 3890,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jacobs-pickles-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'raku-new-york-7',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7264988089246,
#                                  'longitude': -73.9866526052356},
#                  'display_phone': '(212) 228-1324',
#                  'distance': 2428.0392489129867,
#                  'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/GEbZnH1jR4n7D5WOJ3urPg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '342 E 6th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10003'},
#                  'name': 'Raku',
#                  'phone': '+12122281324',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 960,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/raku-new-york-7?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'burger-and-lobster-new-york-4',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.74007, 'longitude': -73.99344},
#                  'display_phone': '(646) 833-7532',
#                  'distance': 3852.2188529432046,
#                  'id': 'UA2M9QFZghe-9th2KwLoWQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/1rHd7F4zztAsScwzM0vDmw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '39 W 19th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10011'},
#                  'name': 'Burger & Lobster',
#                  'phone': '+16468337532',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 5272,
#                  'transactions': ['restaurant_reservation',
#                                   'pickup',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/burger-and-lobster-new-york-4?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'uglyduckling-brooklyn',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.686023,
#                                  'longitude': -73.991302},
#                  'display_phone': '(718) 451-3825',
#                  'distance': 2174.2838817065267,
#                  'id': 'CwOAKJdX8AMz5iAoA-ZEuA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/sCDU8uosDuxp26wjxq4p4g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '166 Smith St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': 'Uglyduckling',
#                  'phone': '+17184513825',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 457,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/uglyduckling-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'boucherie-west-village-new-york-3',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.733063,
#                                  'longitude': -74.0028772},
#                  'display_phone': '(212) 837-1616',
#                  'distance': 3155.0505772747442,
#                  'id': 's3jou_L_LVYGkNHiuhjlew',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-5TXMVrjARsqKQHDg-hKbQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '99 7th Ave S',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10014'},
#                  'name': 'Boucherie West Village',
#                  'phone': '+12128371616',
#                  'price': '$$$',
#                  'rating': 4.5,
#                  'review_count': 1262,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/boucherie-west-village-new-york-3?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'joes-shanghai-new-york-2',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7146691442891,
#                                  'longitude': -73.9977602206654},
#                  'display_phone': '(212) 233-8888',
#                  'distance': 1066.5085498349097,
#                  'id': '0CjK3esfpFcxIopebzjFxA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ekUo5egd4dlE7zJyb4-Leg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '9 Pell St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10013'},
#                  'name': "Joe's Shanghai",
#                  'phone': '+12122338888',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 5939,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'nonono-new-york-6',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.74545, 'longitude': -73.98499},
#                  'display_phone': '(646) 707-3227',
#                  'distance': 4515.897681612123,
#                  'id': 'qm1J_dPA5IHij1oAnoZwHw',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yhZYzx5cnn8SFFF8eZdRHw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '118 Madison Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10016'},
#                  'name': 'nonono',
#                  'phone': '+16467073227',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 506,
#                  'transactions': ['restaurant_reservation',
#                                   'pickup',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/nonono-new-york-6?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'aunt-jakes-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7190315,
#                                  'longitude': -73.9977161},
#                  'display_phone': '(646) 858-0470',
#                  'distance': 1538.0627375870665,
#                  'id': 'I2lgw_7DUnwD92ND4PN-Ow',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/hMhn_lnES3QWc4Gtihvr0A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '149 Mulberry St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10013'},
#                  'name': "Aunt Jake's",
#                  'phone': '+16468580470',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1348,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/aunt-jakes-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'chow-house-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.72915, 'longitude': -74.00072},
#                  'display_phone': '(212) 837-1021',
#                  'distance': 2692.4401801037266,
#                  'id': '0dDCDQz7DrKkSvu9h2hcQw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RjYtwkmpojua4JmC_jXu0w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '181 Bleecker St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10012'},
#                  'name': 'Chow House',
#                  'phone': '+12128371021',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 316,
#                  'transactions': ['restaurant_reservation',
#                                   'pickup',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/chow-house-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'jajaja-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7141530317142,
#                                  'longitude': -73.9904247969389},
#                  'display_phone': '(646) 883-5453',
#                  'distance': 1021.7274074140097,
#                  'id': 'XipQLDbyTl5tsLlyzAWzug',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6HT76TsvGr6XtRVzBi4S_g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '162 E Broadway',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10002'},
#                  'name': 'Jajaja',
#                  'phone': '+16468835453',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 794,
#                  'transactions': ['restaurant_reservation',
#                                   'pickup',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/jajaja-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'root-and-bone-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.72272, 'longitude': -73.98334},
#                  'display_phone': '(646) 682-7080',
#                  'distance': 2129.537859707603,
#                  'id': 'ULt3kmA0_hbZ3j6cMORCaA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2WM96Qsx-7o11LNp1Lin9A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '200 E 3rd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10009'},
#                  'name': 'Root & Bone',
#                  'phone': '+16466827080',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1546,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/root-and-bone-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'sweet-chick-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7217399,
#                                  'longitude': -73.98739},
#                  'display_phone': '(646) 657-0233',
#                  'distance': 1901.1018520082853,
#                  'id': '8F81LrdFm6P5kkFpsw0n0w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/2OGtgpC5YYEZ2yOF93o45g/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '178 Ludlow St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10002'},
#                  'name': 'Sweet Chick',
#                  'phone': '+16466570233',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1541,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/sweet-chick-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'julianas-pizza-brooklyn-5',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.7026153030093,
#                                  'longitude': -73.9934159993549},
#                  'display_phone': '(718) 596-6700',
#                  'distance': 323.20506308227306,
#                  'id': 'ysqgdbSrezXgVwER2kQWKA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '19 Old Fulton St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': "Juliana's Pizza",
#                  'phone': '+17185966700',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 2079,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'thursday-kitchen-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7275, 'longitude': -73.9838},
#                  'display_phone': '',
#                  'distance': 2613.42601480514,
#                  'id': 'fVbUVAiLiGgLA_nxBFxyww',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5P_HFhM6w8cRK3IiCzrNTQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '424 E 9th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10009'},
#                  'name': 'Thursday Kitchen',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1242,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/thursday-kitchen-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'jacks-wife-freda-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.72213, 'longitude': -73.99756},
#                  'display_phone': '(212) 510-8550',
#                  'distance': 1874.7368920314377,
#                  'id': 'Me4TxTbPPQZQopW1wOGx5g',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TRJ5LNNH7UAybD4TlCCf2Q/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '224 Lafayette St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10012'},
#                  'name': "Jack's Wife Freda",
#                  'phone': '+12125108550',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1823,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/jacks-wife-freda-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'tonchin-new-york-new-york',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7502727,
#                                  'longitude': -73.9844951},
#                  'display_phone': '(646) 692-9912',
#                  'distance': 5052.538311265594,
#                  'id': 'OFfZUS-nu6NDnsWe1B2bUQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EA5igkg5gxqHxDcM4YA6hA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '13 W 36th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10018'},
#                  'name': 'TONCHIN NEW YORK',
#                  'phone': '+16466929912',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 915,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/tonchin-new-york-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'les-enfants-de-boheme-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7136187,
#                                  'longitude': -73.9888503},
#                  'display_phone': '(646) 476-4843',
#                  'distance': 1026.2110364656392,
#                  'id': 'qOomR3AwClOGpV1HdqOTFg',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/I1V4kucJO69x8L8UhDwiiA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '177 Henry St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10002'},
#                  'name': 'Les Enfants de Boheme',
#                  'phone': '+16464764843',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 222,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/les-enfants-de-boheme-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'fishmarket-restaurant-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#                  'display_phone': '(917) 363-8101',
#                  'distance': 671.0784555500173,
#                  'id': 'LpVbI-E9C-CSp7WhU5h2Iw',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BxY50B6ntFYQa8COuI1Fog/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '111 South St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10038'},
#                  'name': 'Fishmarket Restaurant',
#                  'phone': '+19173638101',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 535,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'juanchis-burger-brooklyn',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.713003,
#                                  'longitude': -73.958863},
#                  'display_phone': '(929) 295-0147',
#                  'distance': 3102.797689822998,
#                  'id': 'dkAj-3gmkvdA4XkJmw6hCw',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/EqmJxpRSEgnacjHr3bdIEQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '225 S 1st St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': "Juanchi's Burger",
#                  'phone': '+19292950147',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 366,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/juanchis-burger-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'balzem-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.721408,
#                                  'longitude': -73.995415},
#                  'display_phone': '(646) 837-7033',
#                  'distance': 1777.534042874945,
#                  'id': 'StF9WWWbrRzEOmNAcEINcA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/h3NWzD0mw_JJ8F03XowUaA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '202 Mott St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10012'},
#                  'name': 'Balzem',
#                  'phone': '+16468377033',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 413,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/balzem-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'trattoria-trecolori-new-york',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.75998, 'longitude': -73.98671},
#                  'display_phone': '(212) 997-4540',
#                  'distance': 6083.735166572698,
#                  'id': 'DoSU8IPq-Py_YV3kYmXPfQ',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/G8vBgHxbEfoONO0JpLX3Qw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '254 West 47th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10036'},
#                  'name': 'Trattoria Trecolori',
#                  'phone': '+12129974540',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2244,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/trattoria-trecolori-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'chama-mama-new-york',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.7384, 'longitude': -73.99892},
#                  'display_phone': '(646) 438-9007',
#                  'distance': 3690.5460277554907,
#                  'id': 'cTE0e96GYzet799EJeStoQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qRZaBnsI-gfyaSTEIEGzgw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '149 W 14th St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10011'},
#                  'name': 'Chama Mama',
#                  'phone': '+16464389007',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 148,
#                  'transactions': ['restaurant_reservation',
#                                   'pickup',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/chama-mama-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'ippudo-ny-new-york-7',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.73092, 'longitude': -73.99015},
#                  'display_phone': '',
#                  'distance': 2854.3012674083675,
#                  'id': '44SY464xDHbvOcjDzRbKkQ',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zF3EgqHCk7zBUwD2B3WTEA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '65 4th Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10003'},
#                  'name': 'Ippudo NY',
#                  'phone': '',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 9845,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/ippudo-ny-new-york-7?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'lukes-lobster-fidi-new-york',
#                  'categories': [{...}],
#                  'coordinates': {'latitude': 40.7046213003984,
#                                  'longitude': -74.0107793876969},
#                  'display_phone': '(212) 747-1700',
#                  'distance': 1392.7033987694713,
#                  'id': 'kxykwx5qTWBhlMh18MQ82Q',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/C5NV5lfsLo2nJDkx3Or9ig/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '26 S William St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10004'},
#                  'name': "Luke's Lobster FiDi",
#                  'phone': '+12127471700',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1114,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/lukes-lobster-fidi-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'raku-new-york-6',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.72728, 'longitude': -74.00252},
#                  'display_phone': '(212) 989-4797',
#                  'distance': 2522.2670460297,
#                  'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dqDuhxEdkM4M3esKthJjLA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '48 Macdougal St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10012'},
#                  'name': 'Raku',
#                  'phone': '+12129894797',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 302,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/raku-new-york-6?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'cafe-mogador-brooklyn',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.719747,
#                                  'longitude': -73.959993},
#                  'display_phone': '(718) 486-9222',
#                  'distance': 3299.5306167935732,
#                  'id': 'jAaVnUKLITkuhzwXIe0vLQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/zbE8vsLW5Flpt3GMW_4UOA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '133 Wythe Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11211'},
#                  'name': 'Cafe Mogador',
#                  'phone': '+17184869222',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 1132,
#                  'transactions': ['delivery'],
#                  'url': 'https://www.yelp.com/biz/cafe-mogador-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'atrium-dumbo-brooklyn',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7033899,
#                                  'longitude': -73.9904923},
#                  'display_phone': '(718) 858-1095',
#                  'distance': 392.6441573431464,
#                  'id': 'hmdm-dO72hLsMQwQRcGEUQ',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TAog5s7slOJ0778OGRzuWQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '15 Main St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': 'Atrium Dumbo',
#                  'phone': '+17188581095',
# ...
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y90HXuKlFmHl42ZNrL8q1A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '79 Chrystie St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10002'},
#                  'name': 'Wah Fung No 1 Fast Food',
#                  'phone': '+12129255175',
#                  'price': '$',
#                  'rating': 4.5,
#                  'review_count': 1322,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/wah-fung-no-1-fast-food-new-york-3?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': '99-favor-taste-new-york-12',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7176199,
#                                  'longitude': -73.99249},
#                  'display_phone': '(646) 682-9162',
#                  'distance': 1348.6324758108813,
#                  'id': 'Xf6e3HaP0AgMBxY7dEDkOA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3WBk8VLxBAWeXOSqvYoXgw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '285 Grand St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10002'},
#                  'name': '99 Favor Taste',
#                  'phone': '+16466829162',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 1724,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/99-favor-taste-new-york-12?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'tasty-hand-pulled-noodles-new-york',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7142, 'longitude': -73.99787},
#                  'display_phone': '(212) 791-1817',
#                  'distance': 1020.1959880192533,
#                  'id': '97q5nUQTuBo_h00XCxna2A',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2DBFmAL9f6sS-cc9cA9X2A/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 Doyers St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10013'},
#                  'name': 'Tasty Hand-Pulled Noodles',
#                  'phone': '+12127911817',
#                  'price': '$',
#                  'rating': 4.0,
#                  'review_count': 1555,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/tasty-hand-pulled-noodles-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'lillo-cucina-italiana-brooklyn',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.69023, 'longitude': -73.99634},
#                  'display_phone': '(347) 763-0899',
#                  'distance': 1699.2204952670313,
#                  'id': 'qgY41g_eg0eNzewCXmKcaA',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b2MP6R0g_sfFpnLRnQSduA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '331 Henry St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': 'Lillo Cucina Italiana',
#                  'phone': '+13477630899',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 108,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/lillo-cucina-italiana-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'jane-new-york-2',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.72732, 'longitude': -74.00026},
#                  'display_phone': '(212) 254-7000',
#                  'distance': 2489.0891583664493,
#                  'id': 'uoT2_Wrt1noD6kZOID7tUg',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Q5yrDsPb-Tb7eFQ5s_UB3w/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '100 W Houston St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10012'},
#                  'name': 'Jane',
#                  'phone': '+12122547000',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 3098,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/jane-new-york-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'katzs-delicatessen-new-york',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.722237, 'longitude': -73.98743},
#                  'display_phone': '(212) 254-2246',
#                  'distance': 1954.7472206615387,
#                  'id': 'V7lXZKBDzScDeGB8JmnzSA',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/B6xNx79cSE7bFxqERBYOhg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '205 E Houston St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10003'},
#                  'name': "Katz's Delicatessen",
#                  'phone': '+12122542246',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 11697,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/katzs-delicatessen-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'the-smith-new-york-2',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.755165,
#                                  'longitude': -73.967868},
#                  'display_phone': '(212) 644-2700',
#                  'distance': 5960.16818302934,
#                  'id': 'C-8mGN7lt5rIraO5n-15ug',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fGAZCdyPI8qil5boCzidBA/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '956 2nd Ave',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10022'},
#                  'name': 'The Smith',
#                  'phone': '+12126442700',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2496,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/the-smith-new-york-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'celestine-brooklyn',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.704676,
#                                  'longitude': -73.987975},
#                  'display_phone': '(718) 522-5356',
#                  'distance': 539.4069533813018,
#                  'id': '4aF0F8w7yXX9o5_QFky_ig',
#                  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/J5HuHor_cmVEG6HhQtFeDw/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1 John St',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'Brooklyn',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11201'},
#                  'name': 'Celestine',
#                  'phone': '+17185225356',
#                  'price': '$$$',
#                  'rating': 4.0,
#                  'review_count': 198,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/celestine-brooklyn?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'thep-thai-restaurant-new-york-5',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.77078, 'longitude': -73.95727},
#                  'display_phone': '(212) 899-9995',
#                  'distance': 7905.296713584707,
#                  'id': 'O1fUmxt3kbV-rnyjBtzAfw',
#                  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WymEpZCm4CPRTeVHXVyzXQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '1439 2nd Ave',
#                               'address2': '',
#                               'address3': None,
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10021'},
#                  'name': 'THEP Thai Restaurant',
#                  'phone': '+12128999995',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 721,
#                  'transactions': ['pickup',
#                                   'restaurant_reservation',
#                                   'delivery'],
#                  'url': 'https://www.yelp.com/biz/thep-thai-restaurant-new-york-5?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'bea-new-york',
#                  'categories': [{...}, {...}],
#                  'coordinates': {'latitude': 40.7591968,
#                                  'longitude': -73.9923361},
#                  'display_phone': '(212) 602-1910',
#                  'distance': 5979.210371091945,
#                  'id': 'Rc1lxc5lSKJYd162JHNMfQ',
#                  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iVlolLTkpoSWA_VYtRR2ng/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '403 W 43rd St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10036'},
#                  'name': 'Bea',
#                  'phone': '+12126021910',
#                  'price': '$$',
#                  'rating': 4.0,
#                  'review_count': 2378,
#                  'transactions': ['restaurant_reservation'],
#                  'url': 'https://www.yelp.com/biz/bea-new-york?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'the-alcove-sunnyside',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7459065,
#                                  'longitude': -73.915103},
#                  'display_phone': '(347) 813-4159',
#                  'distance': 8045.510107980188,
#                  'id': 'MNNpsRXe7Wt5m3Jla9Wk0w',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/-Q8lxKzqRRrNrOnYZSHvmg/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '41-11 49th St',
#                               'address2': '',
#                               'address3': '',
#                               'city': 'Sunnyside',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '11104'},
#                  'name': 'The Alcove',
#                  'phone': '+13478134159',
#                  'price': '$$',
#                  'rating': 5.0,
#                  'review_count': 787,
#                  'transactions': [],
#                  'url': 'https://www.yelp.com/biz/the-alcove-sunnyside?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'},
#                 {'alias': 'despaña-new-york-2',
#                  'categories': [{...}, {...}, {...}],
#                  'coordinates': {'latitude': 40.7210686,
#                                  'longitude': -73.9979083},
#                  'display_phone': '(212) 219-5050',
#                  'distance': 1763.7952222218955,
#                  'id': 'cUyfnb3E7HvzNfbTgTjl_Q',
#                  'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vvSCh8Zs1eQLTkNeRL4lLQ/o.jpg',
#                  'is_closed': False,
#                  'location': {'address1': '408 Broome St',
#                               'address2': None,
#                               'address3': '',
#                               'city': 'New York',
#                               'country': 'US',
#                               'display_address': [...],
#                               'state': 'NY',
#                               'zip_code': '10013'},
#                  'name': 'Despaña',
#                  'phone': '+12122195050',
#                  'price': '$$',
#                  'rating': 4.5,
#                  'review_count': 560,
#                  'transactions': ['pickup', 'delivery'],
#                  'url': 'https://www.yelp.com/biz/despa%C3%B1a-new-york-2?adjust_creative=q5lmK9zVOh6EcW2HNIUbhA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=q5lmK9zVOh6EcW2HNIUbhA'}],
#  'region': {'center': {'latitude': 40.70544486444615,
#                        'longitude': -73.99429321289062}},
#  'total': 19000}

# %%
businesses = parsed['businesses']

# %%
#This loop just parses data from the Json request and appends to lists.
for business in businesses:
    name.append(business['name'])
    business_id.append(business['id'])
    city.append(business['location']['city'])
    state.append(business['location']['state'])
    latitude.append(business['coordinates']['latitude'])
    longitude.append(business['coordinates']['longitude'])
    review_count.append(business['review_count'])
    rating.append(business['rating'])
    category.append(business['categories'][0]['title'])
    
    try:
        price.append(business['price'])
    except KeyError:
        price.append(0)

# %%
hawaii_df = pd.DataFrame({
    "Business" : name,
    "Business ID": business_id,
    "City": city,
    "State": state,
    "Category": category,
    "Latitude": latitude,
    "Longitude": longitude,
    "Price":price,
    "Reviews": review_count
})

# %%
hawaii_df.head(100)
# Out:
#                  Business             Business ID           City State  \
# 0   State Bird Provisions  QZQGRJZ4bZCmNoXjs3z1XQ  San Francisco    CA
# 1              Outerlands  aIgbg-WdNmgBb-V63RfRUg  San Francisco    CA
# 2              Home Plate  kesgk8dCRyg3qRDYpuAKGg  San Francisco    CA
# 3       RAW Sugar Factory  jLjbntnlmxsX8gsOxZVUcQ  San Francisco    CA
# 4   Tartine Bakery & Cafe  ri7UUYmx21AgSpRsf4-9QA  San Francisco    CA
# ..                    ...                     ...            ...   ...
# 95            Izakaya KOU  PiY8Ks8KWlIcAvqNdMjvBA  San Francisco    CA
# 96      Anchor Oyster Bar  ZDvIMjJ-7I0561ckM4pAeA  San Francisco    CA
# 97            Black Sands  kIjsWd9EcPgp_wsZjKTDTg  San Francisco    CA
# 98    Bistro Central Parc  W97siDhQbWIVa0MEpcq9iA  San Francisco    CA
# 99                Tacorea  u39mZEYojBiNic3lqKhPNw  San Francisco    CA
#
#               Category   Latitude   Longitude Price  Reviews
# 0   Tapas/Small Plates  37.783740 -122.433005   $$$     2683
# 1   Breakfast & Brunch  37.760254 -122.505020    $$     2235
# 2   Breakfast & Brunch  37.800044 -122.437191    $$     1082
# 3   Breakfast & Brunch  37.764440 -122.421570    $$      476
# 4             Bakeries  37.761425 -122.424051    $$     7767
# ..                 ...        ...         ...   ...      ...
# 95  Tapas/Small Plates  37.784139 -122.432649    $$      766
# 96             Seafood  37.759689 -122.434609   $$$     1470
# 97           Breweries  37.771454 -122.433853    $$      309
# 98              French  37.775023 -122.444270   $$$      924
# 99             Mexican  37.789779 -122.410717    $$     1585
#
# [100 rows x 9 columns]

# %%
hawaii_df.to_csv('test2.csv')
