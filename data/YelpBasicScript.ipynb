# %%
import requests
import json
import pandas as pd
import numpy as np
from pprint import pprint
from config import api_key

name = []
city = []
state = []
category = []
latitude = []
longitude = []
price = []
review_count = []
business_id = []
rating = []

# %%
#testloop


#headers
headers={'Authorization':'Bearer %s' % api_key}
#url for yelp
url='https://api.yelp.com/v3/businesses/search'
#parameters
params = {'term':'smoke shop','location':"Jersey City, NJ", 'limit':50, 'offset': 0}
req=requests.get(url, params=params, headers=headers)

#each time you run this you will burn through your daily amount.
parsed = json.loads(req.text)
businesses = parsed['businesses']
# pprint(parsed, depth=4)

#This loop just parses data from the Json request and appends to lists.
for business in businesses:
    name.append(business['name'])
    business_id.append(business['id'])
    city.append(business['location']['city'])
    state.append(business['location']['state'])
    latitude.append(business['coordinates']['latitude'])
    longitude.append(business['coordinates']['longitude'])
    review_count.append(business['review_count'])
    rating.append(business['rating'])
    category.append(business['categories'][0]['title'])
    
    try:
        price.append(business['price'])
    except KeyError:
        price.append(0)
        
business_df = pd.DataFrame({
    "Business" : name,
    "Business ID": business_id,
    "City": city,
    "State": state,
    "Category": category,
    "Latitude": latitude,
    "Longitude": longitude,
    "Price":price,
    "Reviews": review_count
})
business_df
# Out:
#                              Business             Business ID         City  \
# 0   Smoker's Heaven Smoke & Vape Shop  CzwBI_CQ6EW0j68UMHzJ-g  Jersey City
# 1                          Smoke Shop  Cfn6LOzyDISx-K5MmrgCMA  Jersey City
# 2                      A#1 Smoke Shop  wZINnc3U6HCyceFs3r6F8Q  Jersey City
# 3               Paulus Hook Vape Shop  nFIUiAGZRpXJt3vZJTE8aw  Jersey City
# 4       Jersey City Vape & Smoke Shop  3IaVhoIYG2p3BoBkm3Tlxw  Jersey City
# 5                         Sky Tobacco  auzrfOHW5KlHpOEBTZdd4A  Jersey City
# 6                  Hoboken Smoke Shop  TRM16IfwXsm0XYw6tNOPjg      Hoboken
# 7                     Urge Smoke Shop  9H31VozP9D9amAMhOJ5vnw      Hoboken
# 8                     Urge Smoke Shop  haqOyFXW2rAdDJjQXPNvew   Union City
# 9                    Canal Smoke Shop  z-9RB7fyhUNzSWA6qsXYPw     New York
# 10                     Smoke N Clouds  pVI8VVCwPgM40qV7DqVrDQ     Brooklyn
# 11                   The Smoking Shop  DCABiBZ3J071F9qOjZdx4g     New York
# 12                        200 Tobacco  h4YNGXpHIkv4Xooy0mSwUg     New York
# 13                     Kings Of Smoke  QdxuPWiA09UXkKEaqlHt_Q     New York
# 14                        Smoke Scene  33dLybEPZXG5KWmARAaWEQ     New York
# 15                       Smoke N Vape  e7tLfoO_HdRFEQSsJf_gAQ    Manhattan
# 16                  Herald Smoke Shop  PUDXDZ5ZVpSr5XLao3ArSQ     New York
# 17                  Manhattan Tobacco  t_mbjLirfKKGL7A4dJSynA     New York
# 18                     Hoboken Cigars  TU_CDFQnKIh2S56i-sZZdg      Hoboken
# 19      Davidoff of Geneva Since 1911  UP3vwYzIp3y1d9HtAjc41w     New York
# 20                        Barclay Rex  Bo3rlLSe7V6GNr5N-JuYTw     New York
# 21     Smoke Shop & Convenience Store  yDj04VuZJVZzyjmbNcaj-Q     New York
# 22       Clinton Novelties Smoke Shop  oiEZ0L0XLw6wp4Ew9hL8pw     New York
# 23      Cloud Depot Vape & Smoke Shop  KpyKY2Y--OMdz9tPB-j_rw       Newark
# 24             Midtown Smoke and Vape  w9Vz7XWRZ7oDQANIBBy17Q     New York
# 25                  East West Novelty  rCIxXGpJNK7jEgKiS3l4ZA   Union City
# 26                     Nassau Grocery  bf85XazWE0NGvC90PY-I6g     New York
# 27     Belleville Tobacco & Vape Shop  bC1RwJoq0-pJByjrBzT_ig   Belleville
# 28       Brick City Vape & Smoke shop  uLJO_FGQ1EpPG7rjhO0doA       Newark
# 29                      Status Lounge  RXZe4JHIXGc6NRF4qqbEiQ       Newark
# 30            East Village Smoke Shop  y1zlYkyOv1vr29zN8JQSOw     New York
# 31                         City Smoke  4KVbmq_cyUd-hRQIU4NMbg       Kearny
# 32        Havana On the Hudson Cigars  Ps8Jq6I7KLF6TptiAi57Eg    Weehawken
# 33                     559 Smoke Shop  -hvU8Lf0fHYnOJPqrg829w  South Slope
# 34                          Blue Nile  HfaOkOd2PYNOnonyFl1L6A     New York
# 35                         Canna Boys  p-Kt1cJ54aprKyP83kcrYA     New York
# 36              Rodriguez Best Cigars  ODXqN7XtEBlf04ETWOlyRw  Jersey City
# 37                 Metro Beer & Smoke  YE29xQI-zOdUzVyrSEKVTQ     Brooklyn
# 38                  NYC Smokes & More  -4GDQmgVSMyR56sZNWcd5A     New York
# 39             Jubilee Vape and Smoke  cMKWvKYptCS53j-IJxzALg     New York
# 40                Brooklyn Smoke Shop  q8tmLaEkNBnKufr0aiQxFw     Brooklyn
# 41               Jubilee Smoke & Vape  zIS1f9H_yFb8-nsTQ8jqJQ     New York
# 42                         Cigarillos  gO-c2VQ41cIk_I04kwAYPA     New York
# 43                       Prime Hookah  ECEkgLeTVBlTE-Dt109UVQ      Bayonne
# 44                      DB Smoke shop  hf6flMdJbak_Cpte3Y40vA     Brooklyn
# 45                 Classic Smoke Shop  v8KgY3liJ3xU90YIEsMTlw     New York
# 46              6th avenue smoke shop  sVrrLxWl_wWwnVaX9yBNFQ     New York
# 47                 2nd Ave Smoke Shop  2rrJ-7S_3ibvj1Z7-CWzVg     New York
# 48                 Mikey's Smoke Shop  hBJR0yhqacXqsTh52Vp0Gw     Brooklyn
# 49          Jubilee Smoke & Vape Shop  Y6N-XvjUm0_gIxR5oTD3Gg     New York
#
#    State       Category   Latitude  Longitude Price  Reviews
# 0     NJ     Vape Shops  40.730640 -74.061540     $        5
# 1     NJ     Vape Shops  40.731678 -74.066627    $$        7
# 2     NJ  Tobacco Shops  40.736625 -74.051625    $$        5
# 3     NJ  Tobacco Shops  40.714410 -74.038190    $$        3
# 4     NJ  Tobacco Shops  40.722820 -74.048970    $$        5
# 5     NJ  Tobacco Shops  40.720530 -74.042510    $$       16
# 6     NJ  Tobacco Shops  40.744020 -74.029359   $$$       27
# 7     NJ  Tobacco Shops  40.745010 -74.028920     $        7
# 8     NJ  Tobacco Shops  40.770378 -74.030708    $$       18
# 9     NY     Vape Shops  40.720300 -74.003450    $$        1
# 10    NY     Vape Shops  40.702863 -73.987495    $$        4
# 11    NY  Tobacco Shops  40.733877 -74.001795    $$       54
# 12    NY     Vape Shops  40.754892 -73.988564     0        2
# 13    NY     Vape Shops  40.718872 -73.990843     0        1
# 14    NY  Tobacco Shops  40.763712 -73.981138    $$       16
# 15    NY  Tobacco Shops  40.760391 -73.990799    $$       28
# 16    NY  Tobacco Shops  40.748070 -73.987380     0        1
# 17    NY  Tobacco Shops  40.768155 -73.985720     0        1
# 18    NJ  Tobacco Shops  40.736180 -74.028963    $$       22
# 19    NY  Tobacco Shops  40.711984 -74.015265   $$$        8
# 20    NY  Tobacco Shops  40.704890 -74.008672    $$       23
# 21    NY     Vape Shops  40.727530 -74.000700     0        6
# 22    NY  Tobacco Shops  40.720720 -73.984120   $$$        4
# 23    NJ     Vape Shops  40.728267 -74.160350     $        1
# 24    NY     Vape Shops  40.754377 -73.995745    $$       22
# 25    NJ     Gift Shops  40.781522 -74.020961    $$        4
# 26    NY  Tobacco Shops  40.709250 -74.008800     $        1
# 27    NJ  Tobacco Shops  40.793751 -74.144263     0        1
# 28    NJ     Vape Shops  40.730750 -74.161370     0        1
# 29    NJ    Hookah Bars  40.731653 -74.161259     0        1
# 30    NY  Tobacco Shops  40.729390 -73.984340     $        5
# 31    NJ  Tobacco Shops  40.759972 -74.151496    $$        3
# 32    NJ  Tobacco Shops  40.760345 -74.027877    $$       22
# 33    NY     Vape Shops  40.666140 -73.991970     0        1
# 34    NY  Tobacco Shops  40.733160 -74.004330    $$       25
# 35    NY  Tobacco Shops  40.746639 -73.990601     0        5
# 36    NJ  Tobacco Shops  40.754683 -74.043540    $$        1
# 37    NY     Vape Shops  40.714500 -73.958000     0        2
# 38    NY  Tobacco Shops  40.729331 -74.000738    $$        4
# 39    NY     Vape Shops  40.715110 -74.007580     0        5
# 40    NY  Tobacco Shops  40.681565 -73.975946    $$       33
# 41    NY  Tobacco Shops  40.776928 -73.957250     0        7
# 42    NY  Tobacco Shops  40.725292 -74.002922    $$       22
# 43    NJ  Tobacco Shops  40.662620 -74.118990     $        4
# 44    NY  Tobacco Shops  40.680630 -73.977310    $$        7
# 45    NY  Tobacco Shops  40.728630 -73.999380   $$$        3
# 46    NY     Vape Shops  40.731060 -74.001820     $        4
# 47    NY  Tobacco Shops  40.725941 -73.989212  $$$$        9
# 48    NY  Tobacco Shops  40.690830 -73.991490    $$        2
# 49    NY     Vape Shops  40.739080 -74.000500     0        2

# %%
business_df.to_csv('NewYork.csv')

# %%
new_df = business_df.drop_duplicates(keep=False)

# %%
new_df
# Out:
#                                Business             Business ID      City  \
# 3899  Mable's Smokehouse & Banquet Hall  nsAU6F2vmdnphmfIa_RuWg  Brooklyn
#
#      State  Category   Latitude  Longitude Price  Reviews
# 3899    NY  Barbeque  40.721189    -73.957    $$      813
